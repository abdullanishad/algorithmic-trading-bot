# %%
import pyotp
import configparser
from smartapi import SmartConnect
import pandas as pd
from datetime import datetime
import requests
import numpy as np
import math
from datetime import *
import re
from time import sleep
from time import time as tim
from bs4 import BeautifulSoup
from IPython.display import clear_output
import nsepython
import concurrent
import inflect
from time import strptime
import os


config = configparser.ConfigParser()

# # nishad  cred
token = 'S3N5FR3JZ6OSTM3PBPHJRNWEP4'
config.read('my_credentials.ini')

# # shahabaz cred
# token = 'OTXOCWZA4CU4YP7LUUZCZLOCYM'
# config.read('shahabas_credentials.ini')

client_id = config['angel']['client_id']
password = config['angel']['password']
api_key = config['angel']['api_key']

def intializeSymbolTokenMap():
    url = 'https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json'
    d = requests.get(url).json()
    global token_df
    token_df = 'test inside fun'
    token_df = pd.DataFrame.from_dict(d)
    token_df['expiry'] = pd.to_datetime(token_df['expiry'])
    token_df = token_df.astype({'strike': float})

# fetch token/instrument from dataframe
def getTokenInfo (symbol,exch_seg='NSE',instrumenttype='OPTIDX',strike_price='',pe_ce='CE',expiry=None):
    df = token_df
    strike_price = strike_price*100
    if exch_seg == 'NSE':
        eq_df = df[(df['exch_seg'] == 'NSE') ]
        return eq_df[eq_df['name'] == symbol]
    elif exch_seg == 'NFO' and ((instrumenttype == 'FUTSTK') or (instrumenttype == 'FUTIDX')):
        return df[(df['exch_seg'] == 'NFO') & (df['instrumenttype'] == instrumenttype) & (df['name'] == symbol)].sort_values(by=['expiry'])
    elif exch_seg == 'NFO' and (instrumenttype == 'OPTSTK' or instrumenttype == 'OPTIDX'):
        return df[(df['exch_seg'] == 'NFO') & (df['instrumenttype'] == instrumenttype) & (df['name'] == symbol) & (df['strike'] == strike_price) & (df['symbol'].str.endswith(pe_ce))].sort_values(by=['expiry'])

intializeSymbolTokenMap()
obj=SmartConnect(api_key=api_key)
data = obj.generateSession(client_id,password,pyotp.TOTP(token).now())
refreshToken= data['data']['refreshToken']
feedToken=obj.getfeedToken()
userProfile= obj.getProfile(refreshToken)
print(userProfile)
# Out:
# {'status': True, 'message': 'SUCCESS', 'errorcode': '', 'data': {'clientcode': 'A471478', 'name': 'ABDULLA NISHAD', 'email': '', 'mobileno': '', 'exchanges': ['bse_cm', 'nse_cm', 'nse_fo'], 'products': ['BO', 'NRML', 'CO', 'CNC', 'MIS', 'MARGIN'], 'lastlogintime': '', 'broker': ''}}

# %%
symbol = 'BANKNIFTY'
payload = nsepython.nse_optionchain_scrapper(symbol)
currentExpiry,dte = nsepython.nse_expirydetails(payload,0)
p = inflect.engine()
day = currentExpiry.strftime("%d")
month = currentExpiry.strftime("%B")
day = p.ordinal(day)
expiry_folder_name = 'Expiry ' + day +' '+ month
expiry_folder_name

# create a folder with expiry name
directory = expiry_folder_name
parent_dir = "C:/Users/nishad/Desktop/backtesting app/historical data digger"
path = os.path.join(parent_dir, directory)
os.mkdir(path)
print("Directory '% s' created" % directory)
# Out:
# Directory 'Expiry 25th January' created

# %%
def fetch_single_strike_history_and_save_to_csv(symbol,strike):
    q = []
    for i in range(22, 0, -1):
        f = currentExpiry - timedelta(days=i)
        t = currentExpiry - timedelta(days=i-1)
        historicParam = {
             "exchange": "NFO",
             "symboltoken": symbol,
             "interval": "ONE_MINUTE",
             "fromdate": str(f) + " 09:15",
             "todate": str(t) + " 15:30"
        }
        try:
            x = obj.getCandleData(historicParam)
            sleep(0.1)
        except:
            try:
                x = obj.getCandleData(historicParam)
                sleep(1)
            except:
                continue
        if x['data'] != None:
            q += x['data']
    df = pd.DataFrame(q)
    if not df.empty:
        df['date'] = df[0].apply(lambda x: x[:10])
        df[0] = df[0].apply(lambda x: x[11:16])
        first_column = df.pop('date')
        df.insert(0, 'date', first_column)
        df['date'] = df['date'].apply(lambda x: x.replace('-','/'))
        ind = 'BANKNIFTY' + strike
        df['ind'] = ind
        df.set_index('ind',inplace=True)
        df.columns = df.iloc[0]
        df.drop_duplicates(inplace=True)
        df.to_csv(f'{expiry_folder_name}/{ind}.csv',header=False)
        x = pd.read_csv(f'{expiry_folder_name}/{ind}.csv')
        print(ind)

# %% [markdown]
# ### body of the program

# %%
for i in range(25000,60000,100):
    ce = getTokenInfo(symbol,'NFO','OPTIDX',i,'CE')
    pe = getTokenInfo(symbol,'NFO','OPTIDX',i,'PE')
    ce = ce[ce['expiry'] == str(currentExpiry)]
    pe = pe[pe['expiry'] == str(currentExpiry)]
    if not ce.empty:
        strike = str(i) + 'CE'
        ce_token = ce.iloc[0]['token']
        fetch_single_strike_history_and_save_to_csv(ce_token,strike)
    if not pe.empty:
        strike = str(i) + 'PE'
        pe_token = pe.iloc[0]['token']
        fetch_single_strike_history_and_save_to_csv(pe_token,strike)
# Out:
# BANKNIFTY31500CE
# BANKNIFTY31500PE
# BANKNIFTY32000CE
# BANKNIFTY32000PE
# BANKNIFTY32500CE
# BANKNIFTY32500PE
# BANKNIFTY33000CE
# BANKNIFTY33000PE
# BANKNIFTY33500CE
# BANKNIFTY33500PE
# BANKNIFTY34000CE
# BANKNIFTY34000PE
# BANKNIFTY34500CE
# BANKNIFTY34500PE
# BANKNIFTY35000CE
# BANKNIFTY35000PE
# BANKNIFTY35500CE
# BANKNIFTY35500PE
# BANKNIFTY36000CE
# BANKNIFTY36000PE
# BANKNIFTY36500CE
# BANKNIFTY36500PE
# BANKNIFTY37000CE
# BANKNIFTY37000PE
# BANKNIFTY37300PE
# BANKNIFTY37400PE
# BANKNIFTY37500CE
# BANKNIFTY37500PE
# BANKNIFTY37600PE
# BANKNIFTY37700PE
# BANKNIFTY37800PE
# BANKNIFTY37900PE
# BANKNIFTY38000CE
# BANKNIFTY38000PE
# BANKNIFTY38100PE
# BANKNIFTY38200PE
# BANKNIFTY38300PE
# BANKNIFTY38400PE
# BANKNIFTY38500CE
# BANKNIFTY38500PE
# BANKNIFTY38600PE
# BANKNIFTY38700CE
# BANKNIFTY38700PE
# BANKNIFTY38800CE
# BANKNIFTY38800PE
# BANKNIFTY38900PE
# BANKNIFTY39000CE
# BANKNIFTY39000PE
# BANKNIFTY39100PE
# BANKNIFTY39200PE
# BANKNIFTY39300CE
# BANKNIFTY39300PE
# BANKNIFTY39400PE
# BANKNIFTY39500CE
# BANKNIFTY39500PE
# BANKNIFTY39600PE
# BANKNIFTY39700CE
# BANKNIFTY39700PE
# BANKNIFTY39800PE
# BANKNIFTY39900PE
# BANKNIFTY40000CE
# BANKNIFTY40000PE
# BANKNIFTY40100CE
# BANKNIFTY40100PE
# BANKNIFTY40200CE
# BANKNIFTY40200PE
# BANKNIFTY40300CE
# BANKNIFTY40300PE
# BANKNIFTY40400CE
# BANKNIFTY40400PE
# BANKNIFTY40500CE
# BANKNIFTY40500PE
# BANKNIFTY40600CE
# BANKNIFTY40600PE
# BANKNIFTY40700CE
# BANKNIFTY40700PE
# BANKNIFTY40800CE
# BANKNIFTY40800PE
# BANKNIFTY40900CE
# BANKNIFTY40900PE
# BANKNIFTY41000CE
# BANKNIFTY41000PE
# BANKNIFTY41100CE
# BANKNIFTY41100PE
# BANKNIFTY41200CE
# BANKNIFTY41200PE
# BANKNIFTY41300CE
# BANKNIFTY41300PE
# BANKNIFTY41400CE
# BANKNIFTY41400PE
# BANKNIFTY41500CE
# BANKNIFTY41500PE
# BANKNIFTY41600CE
# BANKNIFTY41600PE
# BANKNIFTY41700CE
